# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
img = cv2.imread(r'C:\Users\junio\Desktop\OpenCV-master-v6_00\DATA\flat_chessboard.png')
img1 = cv2.imread(r'C:\Users\junio\Desktop\OpenCV-master-v6_00\DATA\gorilla.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img1_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
plt.imshow(img1_rgb)

# %%
img_rgb.shape
# Out:
# (352, 352, 3)

# %%
img1_rgb.shape
# Out:
# (1295, 1955, 3)

# %%
img_rgb = cv2.resize(img, (1200,1200))
img1_rgb = cv2.resize(img1, (1200,1200))

# %%
plt.imshow(img_rgb)

# %%
blended = cv2.addWeighted(img_rgb, 0.6, img1_rgb, 0.4, gamma=5)
plt.imshow(blended, cmap='gray')

# %%
img = cv2.imread(r'C:\Users\junio\Desktop\OpenCV-master-v6_00\DATA\flat_chessboard.png')
img1 = cv2.imread(r'C:\Users\junio\Desktop\OpenCV-master-v6_00\DATA\gorilla.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (352, 352, 3)

# %%
img1.shape
# Out:
# (1295, 1955, 3)

# %%
large_img = img1
small_img = img

# %%
x_offset =0
y_offset =0

# %%
x_end = x_offset + small_img.shape[1]
y_end = y_offset + small_img.shape[0]

# %%
large_img[y_offset:y_end, x_offset:x_end] = small_img
plt.imshow(large_img)

# %%
img = cv2.imread(r'C:\Users\junio\Desktop\OpenCV-master-v6_00\DATA\flat_chessboard.png')
img1 = cv2.imread(r'C:\Users\junio\Desktop\OpenCV-master-v6_00\DATA\gorilla.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# %%
img.shape
img = cv2.resize(img, (600,600))
img.shape
# Out:
# (600, 600, 3)

# %%
img1.shape
# Out:
# (1295, 1955, 3)

# %%
x_offset = 1295 - 600
y_offset = 1955 - 600

# %%
# Region of Interest (ROI)
roi = img1[x_offset:1295, y_offset:1955]
plt.imshow(roi)

# %%
img2gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img2gray.shape
# Out:
# (600, 600)

# %%
plt.imshow(img2gray, cmap = 'gray')

# %%
mask_inv = cv2.bitwise_not(img2gray)
img2gray.shape
# Out:
# (600, 600)

# %%
plt.imshow(img2gray, cmap = 'gray')

# %%
white_background = np.full(img2gray.shape, 255, dtype=np.uint8)

# %%
bk = cv2.bitwise_or(white_background, white_background, mask=mask_inv)

# %%
bk.shape
# Out:
# (600, 600)
