# %%
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r"C:\Users\junio\Desktop\OpenCV-master-v6_00\DATA\dog_backpack.jpg")

# %%
img.shape
# Out:
# (1401, 934, 3)

# %%
plt.imshow(img)

# %%
#OpenCv BGR
#matplotlib RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_gray = cv2.imread(r"C:\Users\junio\Desktop\OpenCV-master-v6_00\DATA\dog_backpack.jpg", cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap= 'gray')

# %%
img = cv2.resize(img_rgb, (1300,275))
img.shape
# Out:
# (275, 1300, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
img1 = cv2.resize(img_rgb, (0,0), img_rgb, w_ratio, h_ratio)

# %%
img1.shape
# Out:
# (700, 467, 3)

# %%
plt.imshow(img1)

# %%
fig = plt.figure (figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(img1)
